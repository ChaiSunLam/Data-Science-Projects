# %%
#Import necessary modules

#Data manipulation/Graphing
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#Models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB

#Evaluation
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
#import dataset, lines commented out no longer needed, mainly used for checking
dataset = pd.read_csv(r"C:\Users\Jason Lam\Downloads\dermatology_database_1.csv")

#Replace ? with NaN values
dataset = dataset.replace('?',np.nan)
dataset = dataset.dropna()

# %%
dataset
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                    0                   0                         0
# 1                    0                   0                         0
# 2                    3                   0                         3
# 3                    0                   0                         0
# 4                    2                   0                         2
# ..                 ...                 ...                       ...
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                             1                  0  ...
# 1                             1                  1  ...
# 2                             0                  0  ...
# 3                             3                  2  ...
# 4                             0                  0  ...
# ..                          ...                ...  ...
# 361                           0                  0  ...
# 362                           0                  0  ...
# 363                           0                  0  ...
# 364                           0                  0  ...
# 365                           3                  3  ...
#
#      disappearance_granular_layer  vacuolisation_damage_basal_layer  \
# 0                               0                                 0
# 1                               0                                 0
# 2                               0                                 2
# 3                               3                                 0
# 4                               2                                 3
# ..                            ...                               ...
# 361                             0                                 0
# 362                             1                                 0
# 363                             0                                 3
# 364                             0                                 2
# 365                             2                                 0
#
#      spongiosis  saw_tooth_appearance_retes  follicular_horn_plug  \
# 0             3                           0                     0
# 1             0                           0                     0
# 2             3                           2                     0
# 3             0                           0                     0
# 4             2                           3                     0
# ..          ...                         ...                   ...
# 361           1                           0                     0
# 362           1                           0                     0
# 363           0                           3                     0
# 364           0                           1                     0
# 365           0                           0                     0
#
#      perifollicular_parakeratosis  inflammatory_mononuclear_infiltrate  \
# 0                               0                                    1
# 1                               0                                    1
# 2                               0                                    2
# 3                               0                                    3
# 4                               0                                    2
# ..                            ...                                  ...
# 361                             0                                    2
# 362                             0                                    2
# 363                             0                                    2
# 364                             0                                    2
# 365                             0                                    3
#
#      band_like_infiltrate  age  class
# 0                       0   55      2
# 1                       0    8      1
# 2                       3   26      3
# 3                       0   40      1
# 4                       3   45      3
# ..                    ...  ...    ...
# 361                     0   25      4
# 362                     0   36      4
# 363                     3   28      3
# 364                     3   50      3
# 365                     0   35      1
#
# [358 rows x 35 columns]

# %%
#Establish Variables
x = dataset.drop(['class'], axis = 1)
y = dataset['class']

# %%
#Split Training and Test Data
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
#Linear Regression Model and its score
linear_regression = LinearRegression()
linear_regression.fit(x_train, y_train)
lin_pred = linear_regression.predict(x_test)
print('Score: '+str(linear_regression.score(x_train, y_train)))
# Out:
# Score: 0.8914244742403442

# %%
#Decision Tree and its statistics

decision_tree = DecisionTreeClassifier(random_state = 0 , max_depth = 5)
decision_tree.fit(x_train, y_train)
dt_pred = decision_tree.predict(x_test)
print('Score: '+str(decision_tree.score(x_train, y_train)))
print('Accuracy Score: '+str(accuracy_score(y_test , dt_pred)))
cm = confusion_matrix(y_test , dt_pred)
print('Confusion matrix\n\n', cm)
# Out:
# Score: 0.972
# Accuracy Score: 0.8796296296296297
# Confusion matrix
#
#  [[30  1  0  0  0  0]
#  [ 1 17  0  1  0  0]
#  [ 0  0 17  1  0  0]
#  [ 0  6  0 15  0  0]
#  [ 1  0  0  0  9  0]
#  [ 0  1  1  0  0  7]]

# %% [markdown]
# From the Confusion Matrix and the Accuracy Score above, we can tell that the Decision Tree is performing quite well when determining the correct classes. There are a few errors as indicated by the non-zero values outside of the leading diagonal of the matrix.

# %%
#Random Forest and its statistics

random_forest = RandomForestClassifier(random_state = 0 , max_depth = 5)
random_forest.fit(x_train, y_train)
rf_pred = random_forest.predict(x_test)
print('Score: '+str(random_forest.score(x_train, y_train)))
print('Accuracy Score: '+str(accuracy_score(y_test , rf_pred)))
cm = confusion_matrix(y_test , rf_pred)
print('Confusion matrix\n\n', cm)
# Out:
# Score: 0.988
# Accuracy Score: 0.9351851851851852
# Confusion matrix
#
#  [[31  0  0  0  0  0]
#  [ 1 18  0  0  0  0]
#  [ 0  0 18  0  0  0]
#  [ 0  5  0 16  0  0]
#  [ 0  0  0  0 10  0]
#  [ 1  0  0  0  0  8]]

# %% [markdown]
# From the Confusion Matrix and the Accuracy Score above, we can tell that the Random Forest is performing quite well when determining the correct classes, even better than the Decision Tree. There are a few errors as indicated by the non-zero values outside of the leading diagonal of the matrix.

# %%
#SVM and its statistics

supp_vector_machine = svm.SVC()
supp_vector_machine.fit(x_train, y_train)
sv_pred = supp_vector_machine.predict(x_test)
print('Score: '+str(supp_vector_machine.score(x_train, y_train)))
print('Accuracy Score: '+str(accuracy_score(y_test , sv_pred)))
cm = confusion_matrix(y_test , sv_pred)
print('Confusion matrix\n\n', cm)
# Out:
# Score: 0.716
# Accuracy Score: 0.6388888888888888
# Confusion matrix
#
#  [[31  0  0  0  0  0]
#  [ 3 16  0  0  0  0]
#  [ 0  0 18  0  0  0]
#  [ 5 16  0  0  0  0]
#  [ 7  2  0  0  1  0]
#  [ 5  1  0  0  0  3]]

# %% [markdown]
# From the Confusion Matrix and the Accuracy Score above, we can see that the Support Vector Machine (SVM) is not performing as well in terms of predictions, as there are more non-zero values outside of the leading diagonal of the Confusion Matrix.

# %%
gnb = GaussianNB()
y_pred = gnb.fit(x_train, y_train).predict(x_test)
gnb_pred = gnb.predict(x_test)
print('Score: '+str(gnb.score(x_train, y_train)))
print('Accuracy Score: '+str(accuracy_score(y_test , gnb_pred)))
cm = confusion_matrix(y_test , gnb_pred)
print('Confusion matrix\n\n', cm)
# Out:
# Score: 0.904
# Accuracy Score: 0.8518518518518519
# Confusion matrix
#
#  [[31  0  0  0  0  0]
#  [ 0  4  0 12  3  0]
#  [ 0  0 18  0  0  0]
#  [ 0  0  0 21  0  0]
#  [ 0  0  0  0 10  0]
#  [ 0  1  0  0  0  8]]

# %% [markdown]
# From the Confusion Matrix and the Accuracy Score above, we can see that the Gaussian Naive Bayes is performing quite well in terms of predictions, as there are less non-zero values outside of the leading diagonal of the Confusion Matrix, and the accuracy score is over 0.9.

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5fb97_row0_col0, #T_5fb97_row1_col1, #T_5fb97_row2_col2, #T_5fb97_row3_col3, #T_5fb97_row4_col4, #T_5fb97_row5_col5, #T_5fb97_row6_col6, #T_5fb97_row7_col7, #T_5fb97_row8_col8, #T_5fb97_row9_col9, #T_5fb97_row10_col10, #T_5fb97_row11_col11, #T_5fb97_row12_col12, #T_5fb97_row13_col13, #T_5fb97_row14_col14, #T_5fb97_row15_col15, #T_5fb97_row16_col16, #T_5fb97_row17_col17, #T_5fb97_row18_col18, #T_5fb97_row19_col19, #T_5fb97_row20_col20, #T_5fb97_row21_col21, #T_5fb97_row22_col22, #T_5fb97_row23_col23, #T_5fb97_row24_col24, #T_5fb97_row25_col25, #T_5fb97_row26_col26, #T_5fb97_row27_col27, #T_5fb97_row28_col28, #T_5fb97_row29_col29, #T_5fb97_row30_col30, #T_5fb97_row31_col31, #T_5fb97_row32_col32, #T_5fb97_row33_col33, #T_5fb97_row34_col34 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_5fb97_row0_col2, #T_5fb97_row10_col30, #T_5fb97_row16_col9, #T_5fb97_row22_col2, #T_5fb97_row25_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5fb97_row0_col3, #T_5fb97_row1_col26, #T_5fb97_row1_col28, #T_5fb97_row3_col16, #T_5fb97_row3_col22, #T_5fb97_row7_col30, #T_5fb97_row12_col6, #T_5fb97_row12_col29, #T_5fb97_row14_col9, #T_5fb97_row19_col4, #T_5fb97_row22_col16, #T_5fb97_row28_col25, #T_5fb97_row30_col5, #T_5fb97_row30_col11, #T_5fb97_row30_col14, #T_5fb97_row30_col26, #T_5fb97_row33_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col4, #T_5fb97_row0_col6, #T_5fb97_row1_col4, #T_5fb97_row2_col3, #T_5fb97_row2_col30, #T_5fb97_row5_col20, #T_5fb97_row6_col5, #T_5fb97_row6_col11, #T_5fb97_row6_col25, #T_5fb97_row6_col26, #T_5fb97_row10_col16, #T_5fb97_row14_col13, #T_5fb97_row19_col6, #T_5fb97_row19_col30, #T_5fb97_row26_col20, #T_5fb97_row33_col31 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col5, #T_5fb97_row4_col1, #T_5fb97_row9_col33, #T_5fb97_row12_col3, #T_5fb97_row12_col5, #T_5fb97_row14_col15, #T_5fb97_row14_col33, #T_5fb97_row15_col4, #T_5fb97_row17_col10, #T_5fb97_row18_col33, #T_5fb97_row27_col29, #T_5fb97_row29_col18, #T_5fb97_row31_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5fb97_row0_col7, #T_5fb97_row0_col29, #T_5fb97_row7_col1, #T_5fb97_row8_col16, #T_5fb97_row30_col0, #T_5fb97_row33_col4, #T_5fb97_row33_col34 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_5fb97_row0_col8, #T_5fb97_row5_col27, #T_5fb97_row20_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5fb97_row0_col9, #T_5fb97_row8_col30, #T_5fb97_row9_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5fb97_row0_col10, #T_5fb97_row3_col33, #T_5fb97_row4_col22, #T_5fb97_row12_col11, #T_5fb97_row12_col26, #T_5fb97_row12_col32, #T_5fb97_row12_col33, #T_5fb97_row16_col0, #T_5fb97_row16_col33, #T_5fb97_row17_col25, #T_5fb97_row29_col9, #T_5fb97_row29_col20 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_5fb97_row0_col11, #T_5fb97_row3_col23, #T_5fb97_row13_col27, #T_5fb97_row15_col29, #T_5fb97_row16_col15, #T_5fb97_row21_col16, #T_5fb97_row30_col18, #T_5fb97_row30_col20, #T_5fb97_row31_col13 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5fb97_row0_col12, #T_5fb97_row0_col16, #T_5fb97_row1_col11, #T_5fb97_row2_col27, #T_5fb97_row22_col6, #T_5fb97_row25_col17, #T_5fb97_row28_col19, #T_5fb97_row32_col19, #T_5fb97_row32_col21 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col13, #T_5fb97_row2_col26, #T_5fb97_row8_col2, #T_5fb97_row13_col23, #T_5fb97_row23_col22, #T_5fb97_row26_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_5fb97_row0_col14, #T_5fb97_row5_col10, #T_5fb97_row25_col12, #T_5fb97_row28_col10, #T_5fb97_row29_col33 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col15, #T_5fb97_row2_col0, #T_5fb97_row8_col29, #T_5fb97_row19_col10, #T_5fb97_row21_col10, #T_5fb97_row23_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_5fb97_row0_col17, #T_5fb97_row2_col34, #T_5fb97_row5_col9, #T_5fb97_row6_col7, #T_5fb97_row13_col6, #T_5fb97_row14_col7, #T_5fb97_row16_col31, #T_5fb97_row23_col29, #T_5fb97_row24_col6, #T_5fb97_row25_col11, #T_5fb97_row25_col24, #T_5fb97_row25_col26, #T_5fb97_row25_col31, #T_5fb97_row26_col9, #T_5fb97_row28_col20, #T_5fb97_row30_col2, #T_5fb97_row32_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col18, #T_5fb97_row4_col2, #T_5fb97_row10_col18, #T_5fb97_row30_col15 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5fb97_row0_col19, #T_5fb97_row0_col21, #T_5fb97_row2_col11, #T_5fb97_row4_col15, #T_5fb97_row11_col4, #T_5fb97_row13_col1, #T_5fb97_row16_col19, #T_5fb97_row17_col8, #T_5fb97_row22_col18, #T_5fb97_row23_col13, #T_5fb97_row25_col22 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5fb97_row0_col20, #T_5fb97_row0_col22, #T_5fb97_row3_col34, #T_5fb97_row8_col6, #T_5fb97_row10_col13, #T_5fb97_row16_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5fb97_row0_col23, #T_5fb97_row6_col15, #T_5fb97_row12_col13, #T_5fb97_row18_col0, #T_5fb97_row20_col16, #T_5fb97_row32_col27 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5fb97_row0_col24, #T_5fb97_row2_col10, #T_5fb97_row2_col17, #T_5fb97_row3_col19, #T_5fb97_row3_col21, #T_5fb97_row5_col18, #T_5fb97_row9_col30, #T_5fb97_row14_col21, #T_5fb97_row18_col29, #T_5fb97_row20_col0, #T_5fb97_row29_col23, #T_5fb97_row30_col23, #T_5fb97_row31_col3, #T_5fb97_row33_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5fb97_row0_col25, #T_5fb97_row0_col27, #T_5fb97_row21_col17, #T_5fb97_row31_col19, #T_5fb97_row31_col20 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5fb97_row0_col26, #T_5fb97_row0_col32, #T_5fb97_row11_col18, #T_5fb97_row22_col17, #T_5fb97_row31_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5fb97_row0_col28, #T_5fb97_row0_col33, #T_5fb97_row5_col16, #T_5fb97_row6_col18, #T_5fb97_row11_col0, #T_5fb97_row24_col18, #T_5fb97_row27_col0, #T_5fb97_row30_col13 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_5fb97_row0_col30, #T_5fb97_row12_col7, #T_5fb97_row30_col17 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_5fb97_row0_col31, #T_5fb97_row2_col29, #T_5fb97_row5_col12, #T_5fb97_row7_col20, #T_5fb97_row11_col23, #T_5fb97_row11_col29, #T_5fb97_row17_col28, #T_5fb97_row17_col32, #T_5fb97_row20_col6, #T_5fb97_row22_col4, #T_5fb97_row22_col29, #T_5fb97_row23_col3, #T_5fb97_row24_col23, #T_5fb97_row25_col4, #T_5fb97_row26_col23, #T_5fb97_row26_col29, #T_5fb97_row28_col29, #T_5fb97_row33_col16, #T_5fb97_row34_col20 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5fb97_row0_col34, #T_5fb97_row5_col25, #T_5fb97_row7_col23, #T_5fb97_row16_col17, #T_5fb97_row17_col3, #T_5fb97_row18_col15, #T_5fb97_row24_col30, #T_5fb97_row29_col14, #T_5fb97_row30_col24, #T_5fb97_row30_col32 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5fb97_row1_col0, #T_5fb97_row15_col34 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_5fb97_row1_col2, #T_5fb97_row1_col13, #T_5fb97_row25_col2, #T_5fb97_row32_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_5fb97_row1_col3, #T_5fb97_row7_col6, #T_5fb97_row7_col14, #T_5fb97_row7_col22, #T_5fb97_row12_col2, #T_5fb97_row13_col29, #T_5fb97_row17_col26, #T_5fb97_row21_col6 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_5fb97_row1_col5, #T_5fb97_row3_col2, #T_5fb97_row5_col19, #T_5fb97_row5_col21, #T_5fb97_row11_col19, #T_5fb97_row11_col21, #T_5fb97_row24_col19, #T_5fb97_row26_col19, #T_5fb97_row26_col21, #T_5fb97_row27_col3, #T_5fb97_row28_col1, #T_5fb97_row28_col21, #T_5fb97_row29_col24 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5fb97_row1_col6, #T_5fb97_row1_col12, #T_5fb97_row1_col32, #T_5fb97_row3_col17, #T_5fb97_row6_col24, #T_5fb97_row6_col32, #T_5fb97_row14_col8, #T_5fb97_row14_col22, #T_5fb97_row16_col6, #T_5fb97_row22_col15, #T_5fb97_row23_col6, #T_5fb97_row23_col16, #T_5fb97_row25_col5, #T_5fb97_row26_col25, #T_5fb97_row27_col4, #T_5fb97_row32_col25 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5fb97_row1_col7, #T_5f

# %%
# Create a mask to ignore the diagonal (1.0 values)
mask = np.triu(np.ones_like(corr, dtype=bool), k=1)  # Upper triangle excluding diagonal
stacked_corr = corr.where(mask).stack().reset_index()  # Flatten and filter

# Rename columns for clarity
stacked_corr.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Sort by absolute correlation (descending)
sorted_corr = stacked_corr.reindex(
    stacked_corr['Correlation'].abs().sort_values(ascending=False).index
)

# Get the top N highest correlations (e.g., top 10)
top_correlations = sorted_corr.head(10)
top_correlations
# Out:
#                            Variable 1                        Variable 2  \
# 333              melanin_incontinence  vacuolisation_damage_basal_layer
# 560  vacuolisation_damage_basal_layer        saw_tooth_appearance_retes
# 564  vacuolisation_damage_basal_layer              band_like_infiltrate
# 580              follicular_horn_plug      perifollicular_parakeratosis
# 577        saw_tooth_appearance_retes              band_like_infiltrate
# 339              melanin_incontinence              band_like_infiltrate
# 180                 polygonal_papules  vacuolisation_damage_basal_layer
# 165                 polygonal_papules              melanin_incontinence
# 541             focal_hypergranulosis  vacuolisation_damage_basal_layer
# 547             focal_hypergranulosis              band_like_infiltrate
#
#      Correlation
# 333     0.942366
# 560     0.937678
# 564     0.937120
# 580     0.928843
# 577     0.928171
# 339     0.919119
# 180     0.911598
# 165     0.911177
# 541     0.910004
# 547     0.906516

# %% [markdown]
# From the table above, we can see the variables that are the most closely correlated. Using this, it may be possible to make diagnosis of the conditions more efficient, as the existence of either variable would likely imply the existence of the other.

# %%
# Convert age column to numeric (silently)
dataset['age'] = pd.to_numeric(dataset['age'], errors='coerce')

# Drop NA values without printing
dataset = dataset.dropna(subset=['age']).copy()

# Create figure and plot without returning anything
plt.figure(figsize=(15, 10))
ax = dataset['age'].hist(bins=20)  # Using 20 bins directly is simpler

# Customize the plot
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Age')

# Ensure clean numeric x-axis
min_age = dataset['age'].min()
max_age = dataset['age'].max()
ax.set_xticks(np.linspace(min_age, max_age, 11))  # 10 nice intervals

plt.show()

# %%
#Smoothing out the curves to see what our dataset actually looks like

import seaborn as sns  
sns.kdeplot(dataset['age'], fill=True)
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>
